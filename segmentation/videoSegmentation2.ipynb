# %%
import skvideo.io
import skvideo.utils
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
from skimage.filters import gaussian
from skimage.segmentation import active_contour

# %%
#img = rgb2gray(img)
# define initial segment
s = np.linspace(0, 2*np.pi, 400)
x = 220 + 100*np.cos(s)
y = 100 + 100*np.sin(s)
init = np.array([x, y]).T

# %%
# read video
cap = cv2.VideoCapture('eye.mp4')
success,frame = cap.read()

# %%
snake = active_contour(gaussian(frame, 3),init, alpha=0.015, beta=10, gamma=0.001, multichannel=False)
# Out:
# <ipython-input-36-d28d7f0c4373>:1: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   snake = active_contour(gaussian(frame, 3),init, alpha=0.015, beta=10, gamma=0.001, multichannel=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-d28d7f0c4373> in <module>
# ----> 1 snake = active_contour(gaussian(frame, 3),init, alpha=0.015, beta=10, gamma=0.001, multichannel=False)
#
# TypeError: active_contour() got an unexpected keyword argument 'multichannel'

# %%
plt.imshow(frame)

# %%
# read video
cap = cv2.VideoCapture('eye.mp4')
imageFrames = []
success,frame = cap.read()
while success:
    imageFrames.append(frame)
    snake = active_contour(gaussian(frame, 3),init, alpha=0.015, beta=10, gamma=0.001)
    fig = plt.figure(figsize=(7, 7))
    ax = fig.add_subplot(111)
    plt.gray()
    ax.imshow(img)
    ax.plot(init[:, 0], init[:, 1], '--r', lw=3)
    ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)
    ax.set_xticks([]), ax.set_yticks([])
    ax.axis([0, img.shape[1], img.shape[0], 0])
    
    
    
    
    
    
    #cv2.imshow('Frame',frame)
    #if cv2.waitKey(200) & 0xFF == ord('q'):
      #break
    success,frame = cap.read()
    

    

#cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %%
while cap.isOpened():
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('q'):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# Can't receive frame (stream end?). Exiting ...

# %%
vid = skvideo.io.vread('eye.mp4')
T, M, N, C = vid.shape
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-85478da006b4> in <module>
# ----> 1 vid = skvideo.io.vread('eye.mp4')
#       2 T, M, N, C = vid.shape
#
# ~/anaconda3/lib/python3.8/site-packages/skvideo/io/io.py in vread(fname, height, width, num_frames, as_grey, inputdict, outputdict, backend, verbosity)
#     131     if backend == "ffmpeg":
#     132         # check if FFMPEG exists in the path
# --> 133         assert _HAS_FFMPEG, "Cannot find installation of real FFmpeg (which comes with ffprobe)."
#     134
#     135         if ((height != 0) and (width != 0)):
#
# AssertionError: Cannot find installation of real FFmpeg (which comes with ffprobe).

# %%
eye_vid = skvideo.io.vread('eye.mp4', height=M, width=N, outputdict={"-pix_fmt": "gray"})[:, :, :, 0]
eye_vid = skvideo.utils.vshape(eye_vid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3785d659dc00> in <module>
# ----> 1 eye_vid = skvideo.io.vread('eye.mp4', height=M, width=N, outputdict={"-pix_fmt": "gray"})[:, :, :, 0]
#       2 eye_vid = skvideo.utils.vshape(eye_vid)
#
# NameError: name 'M' is not defined
